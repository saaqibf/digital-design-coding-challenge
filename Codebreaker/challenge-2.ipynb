# %% [markdown]
# # Challenge 2: The decoder 🔐  ⭐
#
# ### ⭐ Worth 3 points
#
# Our informant leaked the shifts. Crack message one with the decoder, then re-aim it at message two.
#
# **To run a cell: click it, then press `Shift + Enter`.** Run every cell that starts with `#❗️Run this cell`. If something gets stuck, press the square Stop button up top and run the cell again.

# %%
#❗️Run this cell
import byte as b
b.the_decoder()

# %% [markdown]
# ### Your turn to change the code
#
# The cell below decodes **message two** with shift 3, and it comes out as nonsense. The informant says the real shift is **7**. Change the 3 to a 7 and run it again.

# %%
#❗️Run this cell, then fix the shift and run it again
import byte as b
print(b.decode(b.message_2(), 3))

# %% [markdown]
# What's the password in the decoded message? Keep it in your head, agents don't write passwords down.
#
# ## 📚 Mission complete!
#
# No informant next time: [Challenge 3](./challenge-3.ipynb).
#
# # <p style='text-align: center;'>🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐</p>
