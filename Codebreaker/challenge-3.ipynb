# %% [markdown]
# # Challenge 3: Brute force 🔐💥  ⭐⭐
#
# ### ⭐⭐ Worth 5 points
#
# Message three arrives with **no leaked shift**. Codebreaker's secret: there are only 26 possibilities. Try them ALL.
#
# **To run a cell: click it, then press `Shift + Enter`.** Run every cell that starts with `#❗️Run this cell`. If something gets stuck, press the square Stop button up top and run the cell again.

# %%
#❗️Run this cell
import byte as b
b.brute_force()

# %% [markdown]
# ### End of Session 1
#
# Check your score below, then take a break.
#
# Session 2 starts at [Challenge 4](./challenge-4.ipynb).

# %%
#❗️Run this cell
b.scoreboard()

# %% [markdown]
# # <p style='text-align: center;'>🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐</p>
