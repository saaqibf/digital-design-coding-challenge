# %% [markdown]
# # Challenge 7: Create your own cipher world 🔐🌍  🔐🔐🔐🔐
#
# ### The creator round · worth 15 points, judged by a classmate
#
# You cracked the Ring's codes. Now build a mission of your own.
#
# **Part 1 — Invent your cipher.** Use the tools below to design a layered secret message: shift it, reverse it, or chain both, any order, any depth. Write a short mission brief to go with it (who sent it, why it matters).
#
# **To run a cell: click it, then press `Shift + Enter`.**

# %%
#❗️Run, then change the message, the shifts, and the layers
import byte as b
secret = "WRITE YOUR SECRET MISSION HERE"
layer1 = b.encode(secret, 8)
layer2 = b.reverse(layer1)
# add more layers if you dare: layer3 = b.encode(layer2, 21)
print(layer2)

# %%
#❗️Cracking station for your classmate
import byte as b
message = "PASTE THE CIPHER HERE"
# tools: b.reverse(message), b.crack(message)
b.crack(message)

# %% [markdown]
# **Part 2 — Trade missions.** Swap ciphers with a classmate. They get your encoded message and your mission brief, nothing else. Double-click this cell to record the exchange:
#
# > **My mission brief:**
#
# > **They cracked it? (their initials):**
#
# > **How long it took them:**
#
# **Scoring the creator round:** your classmate awards up to 15 points: 5 if your cipher held out longer than two minutes, 5 if your mission brief made it fun, 5 if the crack felt satisfying. Peer judging, exactly like real capture-the-flag competitions in cybersecurity, which is a real sport with real scholarships.
#
# # <p style='text-align: center;'>🔐 🔐 🔐 🔐 🔐</p>
