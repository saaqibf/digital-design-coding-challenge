# %% [markdown]
# # Challenge 6: Final mission 🔐🏆  ⭐⭐⭐
#
# ### ⭐⭐⭐ Worth 10 points · The finale
#
# One last message. Brute force fails on all 26 shifts. The Ring layered their cipher.
#
# Everything you've learned comes together: peel one layer, then attack the next.
#
# **To run a cell: click it, then press `Shift + Enter`.** Run every cell that starts with `#❗️Run this cell`. If something gets stuck, press the square Stop button up top and run the cell again.

# %%
#❗️Run this cell
import byte as b
b.final_mission()

# %%
#❗️Your full toolkit. Paste the Ring's message between the quotes and peel the layers.
import byte as b
message = "PASTE THE MESSAGE HERE"
flipped = b.reverse(message)   # peel layer one
b.crack(flipped)               # brute force layer two: scan for English!

# %%
#❗️Run this cell for your final score
b.scoreboard()

# %% [markdown]
# ## 🏆 You finished the whole mission!
#
# **Bonus creator round:** [Challenge 7 ⭐⭐⭐⭐ — Create your own cipher world](./challenge-7.ipynb). Build a layered cipher and trade missions with a classmate.
#
# What you actually did today, in job language:
#
# You learned how encryption transforms information, broke codes with brute force and statistical analysis, designed your own cipher, and defeated a layered defence by decomposing it.
#
# **Careers that start exactly here:** Cybersecurity Analyst · Cryptographer · Penetration Tester · Security Engineer · Digital Forensics Investigator
#
# Every private message you've ever sent was protected by a descendant of what you cracked today.
#
# # <p style='text-align: center;'>🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐</p>

# %% [markdown]
# *Format adapted from the [Callysto](https://www.callysto.ca) hackathon templates (CC-BY). Rebuilt by MindFuel.*
