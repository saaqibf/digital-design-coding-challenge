# %% [markdown]
# # Challenge 1: Codebreaking 101 🔐  🔐
#
# ### 🔐 Worth 3 points
#
# The Caesar cipher slides the alphabet. Learn how the slide works and you can undo it.
#
# **To run a cell: click it, then press `Shift + Enter`.** Run every cell that starts with `#❗️Run this cell`. If something gets stuck, press the square Stop button up top and run the cell again.

# %%
#❗️Run this cell
import byte as b
b.crack_101()

# %% [markdown]
# ## 📚 Mission complete!
#
# Crack your first real message in [Challenge 2](./challenge-2.ipynb).
#
# # <p style='text-align: center;'>🔐 🔐 🔐 🔐 🔐</p>
