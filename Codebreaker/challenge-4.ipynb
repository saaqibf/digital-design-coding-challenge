# %% [markdown]
# # Challenge 4: The frequency lab 🔐📊  ⭐⭐
#
# ### ⭐⭐ Worth 5 points · Session 2 starts here
#
# The Ring's messages got longer. Brute-force scanning gets painful. Enter the elegant weapon: **frequency analysis**, the technique that helped crack the Enigma machine in World War Two.
#
# **To run a cell: click it, then press `Shift + Enter`.** Run every cell that starts with `#❗️Run this cell`. If something gets stuck, press the square Stop button up top and run the cell again.

# %%
#❗️Run this cell
import byte as b
b.frequency_lab()

# %% [markdown]
# ## 📚 Mission complete!
#
# Now switch sides: [Challenge 5](./challenge-5.ipynb).
#
# # <p style='text-align: center;'>🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐🔐</p>
