# %% [markdown]
# # Codebreaker 🔐
#
# ## Mission briefing: welcome to cyber defence
#
# Someone calling themselves **the Cipher Ring** is sending scrambled messages across the network. Your unit intercepts them. Your job: crack them.
#
# Your partner is **Byte**, the unit's code-cracking bot. Byte briefs you, checks your work, and keeps your score.
#
# This is a real field: it's called **cryptography**, and the people who do it professionally work in cybersecurity, intelligence, and at every company that keeps your messages private.
#
# **To run a cell: click it, then press `Shift + Enter`.** Run every cell that starts with `#❗️Run this cell`. If something gets stuck, press the square Stop button up top and run the cell again.

# %% [markdown]
# ### Challenge 0 · worth 1 point each
#
# Join the unit and see your first intercepted message.

# %%
#❗️Run this cell
import byte as b
b.join_the_team()

# %%
#❗️Run this cell
b.first_intercept()

# %% [markdown]
# ## 📚 Mission complete!
#
# Training begins in [Challenge 1](./challenge-1.ipynb).
#
# # <p style='text-align: center;'>🔐 🔐 🔐 🔐 🔐</p>

# %% [markdown]
# *Format adapted from the [Callysto](https://www.callysto.ca) hackathon templates (CC-BY). Rebuilt by MindFuel.*
