# %% [markdown]
# # Challenge 2: Find the headliners 🎵  ⭐
#
# ### ⭐ Worth 3 points
#
# The label boss texted: *who has the biggest audience right now?* Sorting answers ranking questions instantly.
#
# **To run a cell: click it, then press `Shift + Enter`.** Run every cell that starts with `#❗️Run this cell`. If something gets stuck, press the square Stop button up top and run the cell again.

# %%
#❗️Run this cell
import nova as n
n.find_the_headliners()

# %% [markdown]
# ### Your turn to change the code
#
# The cell below sorts by `MonthlyListenersMillions`. **Change the column name** to `StreamsPerSongMillions` and rerun it to find whose songs hit hardest per release.
#
# Then try `SocialFollowersMillions`. One tool, three different answers.

# %%
#❗️Run this cell, then change the column name and run it again
n.sort_by("MonthlyListenersMillions")

# %% [markdown]
# ## 📚 Challenge complete!
#
# [Challenge 3](./challenge-3.ipynb) is where the budget comes in.
#
# # <p style='text-align: center;'>🎵🎵🎵🎵🎵🎵🎵🎵🎵🎵🎵🎵🎵🎵🎵</p>
