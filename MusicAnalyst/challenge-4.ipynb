# %% [markdown]
# # Challenge 4: Charts that convince the boss 🎵📈  ⭐⭐
#
# ### ⭐⭐ Worth 5 points · Session 2 starts here
#
# Numbers convince analysts. **Charts convince everyone else.** Today you make the chart that finds bargain artists.
#
# **To run a cell: click it, then press `Shift + Enter`.** Run every cell that starts with `#❗️Run this cell`. If something gets stuck, press the square Stop button up top and run the cell again.

# %%
#❗️Run this cell
import nova as n
n.value_chart()

# %% [markdown]
# ## 📚 Challenge complete!
#
# [Challenge 5](./challenge-5.ipynb) hands you the keys.
#
# # <p style='text-align: center;'>🎵🎵🎵🎵🎵🎵🎵🎵🎵🎵🎵🎵🎵🎵🎵</p>
