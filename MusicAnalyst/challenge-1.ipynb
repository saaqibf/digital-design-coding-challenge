# %% [markdown]
# # Challenge 1: Read the charts 🎵  🎵
#
# ### 🎵 Worth 3 points
#
# Every analyst's first skill is **reading a table fast**. Rows are artists. Columns are facts.
#
# **To run a cell: click it, then press `Shift + Enter`.** Run every cell that starts with `#❗️Run this cell`. If something gets stuck, press the square Stop button up top and run the cell again.

# %%
#❗️Run this cell
import nova as n
n.read_the_charts()

# %% [markdown]
# ## 📚 Challenge complete!
#
# **What to do next: click the blue link →** [Open Challenge 2](./challenge-2.ipynb)
#
# # <p style='text-align: center;'>🎵 🎵 🎵 🎵 🎵</p>
