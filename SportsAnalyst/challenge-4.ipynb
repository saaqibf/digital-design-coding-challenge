# %% [markdown]
# ![banner](Images/banner.png)
#
# <div style="background:#4B258C;color:white;padding:10px 16px;border-radius:12px;font-size:15px;"><b>MISSION MAP</b> &nbsp; 🟧🟧🟧🟧🏀⬜⬜⬜ &nbsp; <b>You are here: Challenge 4 of 7</b> &nbsp;·&nbsp; Points so far bank as you go, every challenge pays.</div>

# %% [markdown]
# # Challenge 4: Charts that convince the coach 🏀📈  🏀🏀
#
# ### 🏀🏀 Worth 5 points · Session 2 starts here
#
# Numbers convince analysts. **Charts convince everyone else.** Today you make the chart that finds bargain players.
#
# **To run a cell: click it, then press `Shift + Enter`.** Run every cell that starts with `#❗️Run this cell`. If something gets stuck, press the square Stop button up top and run the cell again.

# %%
#❗️Run this cell
# %pip install -q ipywidgets
import scout as s
s.value_chart()

# %% [markdown]
# <div style="background:#e8f5e9;border-left:6px solid #2e7d32;padding:12px 16px;border-radius:8px;"><b style="font-size:18px;">🎉 CHALLENGE 4 COMPLETE! Points banked.</b></div>
#
# <a href="./challenge-5.ipynb" style="display:inline-block;background:#E8871E;color:white;padding:12px 26px;border-radius:26px;font-weight:bold;font-size:17px;text-decoration:none;">▶&nbsp; CLICK HERE FOR CHALLENGE 5</a>
#
#
#
# # <p style='text-align: center;'>🏀 🏀 🏀 🏀 🏀</p>
