# %% [markdown]
# ![banner](Images/banner.png)
#
# <div style="background:#4B258C;color:white;padding:10px 16px;border-radius:12px;font-size:15px;"><b>MISSION MAP</b> &nbsp; 🟧🟧🟧🟧🟧🏀⬜⬜ &nbsp; <b>You are here: Challenge 5 of 7</b> &nbsp;·&nbsp; Points so far bank as you go, every challenge pays.</div>

# %% [markdown]
# # Challenge 5: Your own investigation 🏀🔍  🏀🏀🏀
#
# ### 🏀🏀🏀 Worth 7 points
#
# You know how to sort, filter, and chart. Now **you choose the question.** That's the real job.
#
# **To run a cell: click it, then press `Shift + Enter`.** Run every cell that starts with `#❗️Run this cell`. If something gets stuck, press the square Stop button up top and run the cell again.

# %%
#❗️Run this cell
import scout as s
s.your_call()

# %% [markdown]
# ### Working code to copy and change
#
# **This is the biggest skill you'll take home today:** professionals almost never write code from a blank page. They find working code, understand it, and bend it to a new question. That move works in every language, every tool, every job, for the rest of your life. Practice it now:
#
# Each cell below works as-is. Copy one, change columns or numbers, and chase a question you care about.

# %%
#❗️Run, then modify: sort by any column
import scout as s
s.sort_by("AssistsPerGame")

# %%
#❗️Run, then modify: filter with your own conditions
import pandas as pd
df = pd.read_csv("data.csv")
result = df[(df.AssistsPerGame >= 5) & (df.SalaryMillions < 25)]
result

# %%
#❗️Run, then modify: chart any two columns
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("data.csv")
plt.scatter(df.ReboundsPerGame, df.SalaryMillions)
plt.xlabel("Rebounds per game")
plt.ylabel("Salary (millions)")
plt.title("My investigation")
plt.show()

# %% [markdown]
# Write one sentence in this cell (double-click to edit) describing what you found:
#
# > *My finding:*
#
# <div style="background:#e8f5e9;border-left:6px solid #2e7d32;padding:12px 16px;border-radius:8px;"><b style="font-size:18px;">🎉 CHALLENGE 5 COMPLETE! Points banked.</b></div>
#
# <a href="./challenge-6.ipynb" style="display:inline-block;background:#E8871E;color:white;padding:12px 26px;border-radius:26px;font-weight:bold;font-size:17px;text-decoration:none;">▶&nbsp; CLICK HERE FOR CHALLENGE 6</a>
#
#
#
# # <p style='text-align: center;'>🏀 🏀 🏀 🏀 🏀</p>
