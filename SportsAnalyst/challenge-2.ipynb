# %% [markdown]
# ![banner](Images/banner.png)
#
# <div style="background:#4B258C;color:white;padding:10px 16px;border-radius:12px;font-size:15px;"><b>MISSION MAP</b> &nbsp; 🟧🟧🏀⬜⬜⬜⬜⬜ &nbsp; <b>You are here: Challenge 2 of 7</b> &nbsp;·&nbsp; Points so far bank as you go, every challenge pays.</div>

# %% [markdown]
# # Challenge 2: Find the scorers 🏀  🏀
#
# ### 🏀 Worth 3 points
#
# The GM texted you: *who are our best scorers?* Sorting answers ranking questions instantly.
#
# **To run a cell: click it, then press `Shift + Enter`.** Run every cell that starts with `#❗️Run this cell`. If something gets stuck, press the square Stop button up top and run the cell again.

# %%
#❗️Run this cell
import scout as s
s.find_the_scorers()

# %% [markdown]
# ### Your turn to change the code
#
# The cell below sorts by `PointsPerGame`. **Change the column name** to `ReboundsPerGame` and rerun it to find the best rebounder.
#
# Then try `AssistsPerGame`. One tool, three different answers.

# %%
#❗️Run this cell, then change the column name and run it again
s.sort_by("PointsPerGame")

# %% [markdown]
# <div style="background:#e8f5e9;border-left:6px solid #2e7d32;padding:12px 16px;border-radius:8px;"><b style="font-size:18px;">🎉 CHALLENGE 2 COMPLETE! Points banked.</b></div>
#
# <a href="./challenge-3.ipynb" style="display:inline-block;background:#E8871E;color:white;padding:12px 26px;border-radius:26px;font-weight:bold;font-size:17px;text-decoration:none;">▶&nbsp; CLICK HERE FOR CHALLENGE 3</a>
#
#
#
# # <p style='text-align: center;'>🏀 🏀 🏀 🏀 🏀</p>
