# %% [markdown]
# ![banner](Images/banner.png)
#
# <div style="background:#4B258C;color:white;padding:10px 16px;border-radius:12px;font-size:15px;"><b>MISSION MAP</b> &nbsp; 🟧🟧🟧🏀⬜⬜⬜⬜ &nbsp; <b>You are here: Challenge 3 of 7</b> &nbsp;·&nbsp; Points so far bank as you go, every challenge pays.</div>

# %% [markdown]
# # Challenge 3: The money question 🏀💰  🏀🏀
#
# ### 🏀🏀 Worth 5 points
#
# Anyone can want the best player. Analysts find the best player **the team can afford**. That means filtering with two conditions at once.
#
# **To run a cell: click it, then press `Shift + Enter`.** Run every cell that starts with `#❗️Run this cell`. If something gets stuck, press the square Stop button up top and run the cell again.

# %%
#❗️Run this cell
# %pip install -q ipywidgets
import scout as s
s.money_question()

# %% [markdown]
# ### End of Session 1
#
# Count your points with the cell below, write the total somewhere safe, and take a break. You earned it.
#
# <a href="./challenge-4.ipynb" style="display:inline-block;background:#E8871E;color:white;padding:12px 26px;border-radius:26px;font-weight:bold;font-size:17px;text-decoration:none;">▶&nbsp; SESSION 2 STARTS HERE: CHALLENGE 4</a>

# %%
#❗️Run this cell
s.scoreboard()

# %% [markdown]
# # <p style='text-align: center;'>🏀 🏀 🏀 🏀 🏀</p>
