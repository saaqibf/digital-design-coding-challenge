# %% [markdown]
# ![banner](Images/banner.png)
#
# <div style="background:#4B258C;color:white;padding:10px 16px;border-radius:12px;font-size:15px;"><b>MISSION MAP</b> &nbsp; 🟧🏀⬜⬜⬜⬜⬜⬜ &nbsp; <b>You are here: Challenge 1 of 7</b> &nbsp;·&nbsp; Points so far bank as you go, every challenge pays.</div>

# %% [markdown]
# # Challenge 1: Read the scouting report 🏀  🏀
#
# ### 🏀 Worth 3 points
#
# Every analyst's first skill is **reading a table fast**. Rows are players. Columns are facts.
#
# **To run a cell: click it, then press `Shift + Enter`.** Run every cell that starts with `#❗️Run this cell`. If something gets stuck, press the square Stop button up top and run the cell again.

# %%
#❗️Run this cell
import scout as s
s.whos_on_the_roster()

# %% [markdown]
# <div style="background:#e8f5e9;border-left:6px solid #2e7d32;padding:12px 16px;border-radius:8px;"><b style="font-size:18px;">🎉 CHALLENGE 1 COMPLETE! Points banked.</b></div>
#
# <a href="./challenge-2.ipynb" style="display:inline-block;background:#E8871E;color:white;padding:12px 26px;border-radius:26px;font-weight:bold;font-size:17px;text-decoration:none;">▶&nbsp; CLICK HERE FOR CHALLENGE 2</a>
#
#
#
# # <p style='text-align: center;'>🏀 🏀 🏀 🏀 🏀</p>
