# %% [markdown]
# ![banner](Images/banner.png)
#
# <div style="background:#4B258C;color:white;padding:10px 16px;border-radius:12px;font-size:15px;"><b>MISSION MAP</b> &nbsp; 🏀⬜⬜⬜⬜⬜⬜⬜ &nbsp; <b>You are here: Challenge 0 of 7</b> &nbsp;·&nbsp; Points so far bank as you go, every challenge pays.</div>

# %% [markdown]
# # Welcome to the Front Office 🏀
#
# ## Day one: you're the new sports analyst
#
# The general manager of your basketball team has money to spend and one question: **which player should we sign?**
#
# You're the analyst. The data has the answer, and over these challenges you'll find it.
#
# Your assistant is **Scout**, the team's data bot. Scout gives hints, checks your answers, and never gets tired.
#
# **To run a cell: click it, then press `Shift + Enter`.** Run every cell that starts with `#❗️Run this cell`. If something gets stuck, press the square Stop button up top and run the cell again.
#
# Save your work any time with `Ctrl + S` (`⌘ + S` on a Mac).

# %% [markdown]
# ### Wait, what's a hackathon? 🏁
#
# A hackathon is an event where people build something real in a fixed amount of time, then show it off at the end. No lectures, no tests. You get a mission, tools, and a clock. Today is yours.
#
# **The three hacker rules for today:**
#
# 1. **Being stuck is normal.** Every professional gets stuck daily. Hints are free, Scout never gets tired, and asking is a skill, not a weakness.
# 2. **Copying working code and changing it is not cheating.** It's literally how professionals work. Every challenge gives you working code to steal from.
# 3. **Done beats perfect.** Bank your points, keep moving, come back if there's time.
#
# At the end, everyone presents one sentence to the room, exactly like demo day at a real hackathon. By then you'll have earned it.

# %% [markdown]
# ### Challenge 0 · worth 1 point each
#
# Meet your database, then make your very first chart. No code writing needed, just run the cells.

# %%
#❗️Run this cell
# %pip install -q ipywidgets
import scout as s
s.meet_the_team()

# %%
#❗️Run this cell
s.first_look()

# %% [markdown]
# <div style="background:#e8f5e9;border-left:6px solid #2e7d32;padding:12px 16px;border-radius:8px;"><b style="font-size:18px;">🎉 CHALLENGE 0 COMPLETE! Points banked.</b></div>
#
# <a href="./challenge-1.ipynb" style="display:inline-block;background:#E8871E;color:white;padding:12px 26px;border-radius:26px;font-weight:bold;font-size:17px;text-decoration:none;">▶&nbsp; CLICK HERE FOR CHALLENGE 1</a>
#
# You've met the data and made a chart.
#
# # <p style='text-align: center;'>🏀 🏀 🏀 🏀 🏀</p>

# %% [markdown]
# *Format adapted from the [Callysto](https://www.callysto.ca) hackathon templates (CC-BY). Rebuilt by MindFuel.*
