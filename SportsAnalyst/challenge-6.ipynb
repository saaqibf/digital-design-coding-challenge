# %% [markdown]
# ![banner](Images/banner.png)
#
# <div style="background:#4B258C;color:white;padding:10px 16px;border-radius:12px;font-size:15px;"><b>MISSION MAP</b> &nbsp; 🟧🟧🟧🟧🟧🟧🏀⬜ &nbsp; <b>You are here: Challenge 6 of 7</b> &nbsp;·&nbsp; Points so far bank as you go, every challenge pays.</div>

# %% [markdown]
# # Challenge 6: The pitch 🏀🎤  🏀🏀🏀
#
# ### 🏀🏀🏀 Worth 10 points · The finale
#
# The GM walks in: *'One sentence. Who do we sign, and why?'*
#
# Every skill from every challenge comes down to this one recommendation, backed by data.
#
# **This is demo day.** After Scout accepts your pitch, you'll say it out loud to the room, one sentence, thirty seconds. Every hackathon on Earth ends this way, and after today you'll have done it too.
#
# **To run a cell: click it, then press `Shift + Enter`.** Run every cell that starts with `#❗️Run this cell`. If something gets stuck, press the square Stop button up top and run the cell again.

# %%
#❗️Run this cell
# %pip install -q ipywidgets
import scout as s
s.the_pitch()

# %%
#❗️Run this cell for your final score
s.scoreboard()

# %% [markdown]
# ## 🏆 You finished the whole challenge!
#
# **Bonus creator round:** <a href="./challenge-7.ipynb" style="display:inline-block;background:#E8871E;color:white;padding:12px 26px;border-radius:26px;font-weight:bold;font-size:17px;text-decoration:none;">▶&nbsp; BONUS ROUND: CREATE YOUR OWN WORLD</a>. Add yourself to the data and design a challenge for a classmate.
#
# Here's what you actually did today, in job language:
#
# You loaded a database, read it, ranked it, filtered it with multiple conditions, visualized it, ran your own investigation, and delivered a data-backed recommendation.
#
# That workflow is the daily job of: sports analysts, business analysts, data scientists, market researchers, epidemiologists, and every Moneyball front office in professional sports.
#
# **Careers that start exactly here:** Sports Analyst · Data Analyst · Data Scientist · Scout · Performance Analyst
#
# # <p style='text-align: center;'>🏀 🏀 🏀 🏀 🏀</p>

# %% [markdown]
# *Format adapted from the [Callysto](https://www.callysto.ca) hackathon templates (CC-BY). Rebuilt by MindFuel.*
