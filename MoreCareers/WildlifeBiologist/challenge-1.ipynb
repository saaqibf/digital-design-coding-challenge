# %% [markdown]
# # Challenge 1: Read the data 🦉  ⭐
#
# ### ⭐ Worth 3 points
#
# Every analyst's first skill is **reading a table fast**. Rows are habitats. Columns are facts.
#
# **To run a cell: click it, then press `Shift + Enter`.** Run every cell that starts with `#❗️Run this cell`. If something gets stuck, press the square Stop button and run the cell again.

# %%
#❗️Run this cell
import mentor as m
m.read_the_table()

# %% [markdown]
# ## 📚 Challenge complete!
#
# Next: [Challenge 2](./challenge-2.ipynb), where you rank them all.
#
# # <p style='text-align: center;'>🦉 🦉 🦉 🦉 🦉 🦉 🦉 🦉 🦉 🦉 🦉 🦉 </p>
