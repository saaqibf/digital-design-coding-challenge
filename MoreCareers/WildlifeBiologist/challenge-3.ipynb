# %% [markdown]
# # Challenge 3: The budget question 🦉💰  🦉🦉
#
# ### 🦉🦉 Worth 5 points
#
# Anyone can want the best. Analysts find the best **the budget allows**: two conditions at once.
#
# **To run a cell: click it, then press `Shift + Enter`.** Run every cell that starts with `#❗️Run this cell`. If something gets stuck, press the square Stop button and run the cell again.

# %%
#❗️Run this cell
import mentor as m
m.the_big_filter()

# %% [markdown]
# ### End of Session 1
#
# Check your score, note it down, take a break. **When Session 2 starts: click the blue link →** [Open Challenge 4](./challenge-4.ipynb)

# %%
#❗️Run this cell
m.scoreboard()

# %% [markdown]
# # <p style='text-align: center;'>🦉 🦉 🦉 🦉 🦉</p>
