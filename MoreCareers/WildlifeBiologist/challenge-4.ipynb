# %% [markdown]
# # Challenge 4: The chart that convinces 🦉📈  ⭐⭐
#
# ### ⭐⭐ Worth 5 points · Session 2 starts here
#
# Numbers convince analysts. **Charts convince the park director.** Today you make the value chart.
#
# **To run a cell: click it, then press `Shift + Enter`.** Run every cell that starts with `#❗️Run this cell`. If something gets stuck, press the square Stop button and run the cell again.

# %%
#❗️Run this cell
import mentor as m
m.value_chart()

# %% [markdown]
# ## 📚 Challenge complete!
#
# [Challenge 5](./challenge-5.ipynb) hands you the keys.
#
# # <p style='text-align: center;'>🦉 🦉 🦉 🦉 🦉 🦉 🦉 🦉 🦉 🦉 🦉 🦉 </p>
