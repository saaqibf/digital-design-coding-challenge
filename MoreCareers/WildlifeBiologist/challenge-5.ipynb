# %% [markdown]
# # Challenge 5: Your own investigation 🦉🔍  ⭐⭐⭐
#
# ### ⭐⭐⭐ Worth 7 points
#
# You can sort, filter, and chart. Now **you choose the question.** That's the real job.
#
# **To run a cell: click it, then press `Shift + Enter`.** Run every cell that starts with `#❗️Run this cell`. If something gets stuck, press the square Stop button and run the cell again.

# %%
#❗️Run this cell
import mentor as m
m.your_call()

# %% [markdown]
# ### Working code to copy and change

# %%
#❗️Run, then modify: sort by any column
import mentor as m
m.sort_by("EndangeredSpecies")

# %%
#❗️Run, then modify: filter with your own conditions
import pandas as pd
df = pd.read_csv("data.csv")
df[(df.SpeciesCount >= 156) & (df.ProtectionCostMillions < 9.8)]

# %%
#❗️Run, then modify: chart any two columns
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("data.csv")
plt.scatter(df.EndangeredSpecies, df.SpeciesCount)
plt.xlabel("EndangeredSpecies")
plt.ylabel("SpeciesCount")
plt.title("My investigation")
plt.show()

# %% [markdown]
# Double-click here and write one sentence about what you found:
#
# > *My finding:*
#
# ## 📚 Challenge complete!
#
# The finale: [Challenge 6](./challenge-6.ipynb).
#
# # <p style='text-align: center;'>🦉 🦉 🦉 🦉 🦉 🦉 🦉 🦉 🦉 🦉 🦉 🦉 </p>
