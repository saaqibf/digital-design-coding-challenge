# %% [markdown]
# # Welcome, new Wildlife Biologist 🦉
#
# ## Day one on the job
#
# You just joined the national parks service. The park director has one big question: **Which habitat gets this year's protection funding?**
#
# You're the analyst. The data has the answer, and over seven challenges you'll find it.
#
# Your assistant is **Ranger**, the team's data bot: hints, answer checking, and your score, always on your side.
#
# **To run a cell: click it, then press `Shift + Enter`.** Run every cell that starts with `#❗️Run this cell`. If something gets stuck, press the square Stop button and run the cell again.

# %% [markdown]
# ### Challenge 0 · worth 1 point each
#
# Meet your database and make your very first chart. No code writing, just run the cells.

# %%
#❗️Run this cell
import mentor as m
m.meet()

# %%
#❗️Run this cell
m.first_look()

# %% [markdown]
# ## 📚 Challenge complete!
#
# **What to do next: click the blue link →** [Open Challenge 1](./challenge-1.ipynb) — it opens right in this window.
#
# # <p style='text-align: center;'>🦉 🦉 🦉 🦉 🦉</p>

# %% [markdown]
# *Format adapted from the [Callysto](https://www.callysto.ca) hackathon templates (CC-BY). Original content by MindFuel.*
