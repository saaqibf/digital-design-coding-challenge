# %% [markdown]
# # Challenge 2: Find the leaders 🦉  ⭐
#
# ### ⭐ Worth 3 points
#
# The park director wants a ranking. Sorting does it in one line.
#
# **To run a cell: click it, then press `Shift + Enter`.** Run every cell that starts with `#❗️Run this cell`. If something gets stuck, press the square Stop button and run the cell again.

# %%
#❗️Run this cell
import mentor as m
m.find_the_leaders()

# %% [markdown]
# ### Your turn to change the code
#
# The cell below sorts by `SpeciesCount`. **Change the column name** to `EndangeredSpecies` and rerun. Then try `AreaSqKm`. One tool, three answers.

# %%
#❗️Run this cell, then change the column name and run it again
import mentor as m
m.sort_by("SpeciesCount")

# %% [markdown]
# ## 📚 Challenge complete!
#
# [Challenge 3](./challenge-3.ipynb) brings in the budget.
#
# # <p style='text-align: center;'>🦉 🦉 🦉 🦉 🦉 🦉 🦉 🦉 🦉 🦉 🦉 🦉 </p>
