# %% [markdown]
# # Challenge 6: The pitch 🦉🎤  🦉🦉🦉
#
# ### 🦉🦉🦉 Worth 10 points · The finale
#
# The park director walks in: *'One sentence. Which habitat gets this year's protection funding? And why?'*
#
# Everything you learned comes down to one recommendation, backed by data.
#
# **To run a cell: click it, then press `Shift + Enter`.** Run every cell that starts with `#❗️Run this cell`. If something gets stuck, press the square Stop button and run the cell again.

# %%
#❗️Run this cell
import mentor as m
m.the_pitch()

# %%
#❗️Run this cell for your final score
m.scoreboard()

# %% [markdown]
# ## 🏆 You finished the whole challenge!
#
# **Bonus creator round:** [Challenge 7 🦉🦉🦉🦉 — Create your own world](./challenge-7.ipynb). Add yourself to the data and design a challenge for a classmate.
#
# What you actually did, in job language: loaded a database, read it, ranked it, filtered it under constraints, visualized it, ran your own investigation, and delivered a data-backed recommendation.
#
# **Careers that start exactly here:** Wildlife Biologist · Conservation Scientist · Park Ecologist · Environmental Data Analyst
#
# # <p style='text-align: center;'>🦉 🦉 🦉 🦉 🦉</p>

# %% [markdown]
# *Format adapted from the [Callysto](https://www.callysto.ca) hackathon templates (CC-BY). Original content by MindFuel.*
